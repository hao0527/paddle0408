# %% [markdown]
# # 作业说明：
# **✓代码跑通**
#
# 请大家根据课上所学内容，在 VGGNet类中补全代码，构造VGG网络，保证程序跑通。在VGG构造成功的基础上，可尝试构造其他网络。
#
# **✓调优**
#
# 思考并动手进行调优，以在验证集上的准确率为评价指标，验证集上准确率越高，得分越高！

# %% [markdown]
# **任务描述：**
#
# 口罩识别，是指可以有效检测在密集人流区域中携带和未携戴口罩的所有人脸，同时判断该者是否佩戴口罩。通常由两个功能单元组成，可以分别完成口罩人脸的检测和口罩人脸的分类。
#
# **本次实践相比生产环境中口罩识别的问题，降低了难度，仅实现人脸口罩判断模型，可实现对人脸是否佩戴口罩的判定**。本实践旨在通过一个口罩识别的案列，让大家理解和掌握如何使用飞桨动态图搭建一个经典的卷积神经网络
#
# **特别提示：本实践所用数据集均来自互联网，请勿用于商务用途。**

# %%
import os
import zipfile
import random
import json
import paddle
import sys
import numpy as np
from PIL import Image
from PIL import ImageEnhance
import paddle.fluid as fluid
from multiprocessing import cpu_count
import matplotlib.pyplot as plt

# %%
'''
参数配置
'''
train_parameters = {
    "input_size": [3, 224, 224],                              #输入图片的shape
    "class_dim": -1,                                          #分类数
    "src_path":"/home/aistudio/work/maskDetect.zip",#原始数据集路径
    "target_path":"/home/aistudio/data/",                     #要解压的路径
    "train_list_path": "/home/aistudio/data/train.txt",       #train.txt路径
    "eval_list_path": "/home/aistudio/data/eval.txt",         #eval.txt路径
    "readme_path": "/home/aistudio/data/readme.json",         #readme.json路径
    "label_dict":{},                                          #标签字典
    "num_epochs": 37,                                         #训练轮数
    "train_batch_size": 8,                                    #训练时每个批次的大小
    "learning_strategy": {                                    #优化函数相关的配置
        "lr": 0.001                                           #超参数学习率
    } 
}

# %% [markdown]
# # **一、数据准备**
#
# （1）解压原始数据集
#
# （2）按照比例划分训练集与验证集
#
# （3）乱序，生成数据列表
#
# （4）构造训练数据集提供器和验证数据集提供器

# %%
def unzip_data(src_path,target_path):
    '''
    解压原始数据集，将src_path路径下的zip包解压至data目录下
    '''
    if(not os.path.isdir(target_path + "maskDetect")):     
        z = zipfile.ZipFile(src_path, 'r')
        z.extractall(path=target_path)
        z.close()

# %%
def get_data_list(target_path,train_list_path,eval_list_path):
    '''
    生成数据列表
    '''
    #存放所有类别的信息
    class_detail = []
    #获取所有类别保存的文件夹名称
    data_list_path=target_path+"maskDetect/"
    class_dirs = os.listdir(data_list_path)  
    #总的图像数量
    all_class_images = 0
    #存放类别标签
    class_label=0
    #存放类别数目
    class_dim = 0
    #存储要写进eval.txt和train.txt中的内容
    trainer_list=[]
    eval_list=[]
    #读取每个类别，['maskimages', 'nomaskimages']
    for class_dir in class_dirs:
        if class_dir != ".DS_Store":
            class_dim += 1
            #每个类别的信息
            class_detail_list = {}
            eval_sum = 0
            trainer_sum = 0
            #统计每个类别有多少张图片
            class_sum = 0
            #获取类别路径 
            path = data_list_path  + class_dir
            # 获取所有图片
            img_paths = os.listdir(path)
            for img_path in img_paths:                                  # 遍历文件夹下的每个图片
                name_path = path + '/' + img_path                       # 每张图片的路径
                if class_sum % 10 == 0:                                 # 每10张图片取一个做验证数据
                    eval_sum += 1                                       # test_sum为测试数据的数目
                    eval_list.append(name_path + "\t%d" % class_label + "\n")
                else:
                    trainer_sum += 1 
                    trainer_list.append(name_path + "\t%d" % class_label + "\n")#trainer_sum测试数据的数目
                class_sum += 1                                          #每类图片的数目
                all_class_images += 1                                   #所有类图片的数目
             
            # 说明的json文件的class_detail数据
            class_detail_list['class_name'] = class_dir             #类别名称，如jiangwen
            class_detail_list['class_label'] = class_label          #类别标签
            class_detail_list['class_eval_images'] = eval_sum       #该类数据的测试集数目
            class_detail_list['class_trainer_images'] = trainer_sum #该类数据的训练集数目
            class_detail.append(class_detail_list)  
            #初始化标签列表
            train_parameters['label_dict'][str(class_label)] = class_dir
            class_label += 1 
            
    #初始化分类数
    train_parameters['class_dim'] = class_dim

   
    
    #乱序  
    random.shuffle(eval_list)
    with open(eval_list_path, 'a') as f:
        for eval_image in eval_list:
            f.write(eval_image) 
            
    random.shuffle(trainer_list)
    with open(train_list_path, 'a') as f2:
        for train_image in trainer_list:
            f2.write(train_image) 

    # 说明的json文件信息
    readjson = {}
    readjson['all_class_name'] = data_list_path                  #文件父目录
    readjson['all_class_images'] = all_class_images
    readjson['class_detail'] = class_detail
    jsons = json.dumps(readjson, sort_keys=True, indent=4, separators=(',', ': '))
    with open(train_parameters['readme_path'],'w') as f:
        f.write(jsons)
    print ('生成数据列表完成！')

# %%
def custom_reader(file_list):
    '''
    自定义reader
    '''
    def reader():
        with open(file_list, 'r') as f:
            lines = [line.strip() for line in f]
            for line in lines:
                img_path, lab = line.strip().split('\t')
                img = Image.open(img_path) 
                if img.mode != 'RGB': 
                    img = img.convert('RGB') 
                img = img.resize((224, 224), Image.BILINEAR)
                img = np.array(img).astype('float32') 
                img = img.transpose((2, 0, 1))  # HWC to CHW 
                img = img/255                # 像素值归一化 
                yield img, int(lab) 
    return reader

# %%
'''
参数初始化
'''
src_path=train_parameters['src_path']
target_path=train_parameters['target_path']
train_list_path=train_parameters['train_list_path']
eval_list_path=train_parameters['eval_list_path']
batch_size=train_parameters['train_batch_size']

'''
解压原始数据到指定路径
'''
unzip_data(src_path,target_path)

'''
划分训练集与验证集，乱序，生成数据列表
'''
#每次生成数据列表前，首先清空train.txt和eval.txt
with open(train_list_path, 'w') as f: 
    f.seek(0)
    f.truncate() 
with open(eval_list_path, 'w') as f: 
    f.seek(0)
    f.truncate() 
#生成数据列表   
get_data_list(target_path,train_list_path,eval_list_path)

'''
构造数据提供器
'''
train_reader = paddle.batch(custom_reader(train_list_path),
                            batch_size=batch_size,
                            drop_last=True)
eval_reader = paddle.batch(custom_reader(eval_list_path),
                            batch_size=batch_size,
                            drop_last=True)
# Out:
# 生成数据列表完成！

# %% [markdown]
# # **二、模型配置**
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/9ca0744272b0449186f766afcabadd598e24679088a4438dafede05a71b7c141)
#
# VGG的核心是五组卷积操作，每两组之间做Max-Pooling空间降维。同一组内采用多次连续的3X3卷积，卷积核的数目由较浅组的64增多到最深组的512，同一组内的卷积核数目是一样的。卷积之后接两层全连接层，之后是分类层。由于每组内卷积层的不同，有11、13、16、19层这几种模型，上图展示一个16层的网络结构。

# %%
class ConvPool(fluid.dygraph.Layer):
    '''卷积+池化'''
    def __init__(self,
                 num_channels,
                 num_filters,
                 filter_size,
                 pool_size,
                 pool_stride,
                 groups,
                 pool_padding=0,
                 pool_type='max',
                 conv_stride=1,
                 conv_padding=0,
                 act=None):
        super(ConvPool, self).__init__()  

        self._conv2d_list = []

        for i in range(groups):
            conv2d = self.add_sublayer(   #返回一个由所有子层组成的列表。
                'bb_%d' % i,
                fluid.dygraph.Conv2D(
                num_channels=num_channels, #通道数
                num_filters=num_filters,   #卷积核个数
                filter_size=filter_size,   #卷积核大小
                stride=conv_stride,        #步长
                padding=conv_padding,      #padding大小，默认为0
                act=act)
            )
        self._conv2d_list.append(conv2d)   

        self._pool2d = fluid.dygraph.Pool2D(
            pool_size=pool_size,           #池化核大小
            pool_type=pool_type,           #池化类型，默认是最大池化
            pool_stride=pool_stride,       #池化步长
            pool_padding=pool_padding      #填充大小
            )

    def forward(self, inputs):
        x = inputs
        for conv in self._conv2d_list:
            x = conv(x)
        x = self._pool2d(x)
        return x

# %% [markdown]
# # 请在以下cell中完成VGG网络的定义

# %%
class VGGNet(fluid.dygraph.Layer):
    '''
    VGG网络
    '''
    def __init__(self):
        super(VGGNet, self).__init__()
        self.hidden1=ConvPool(3,64,3,2,2,2,act='relu')
        self.hidden2=ConvPool(64,128,3,2,2,2,act='relu')
        self.hidden3=ConvPool(128,256,3,2,2,3,act='relu')
        self.hidden4=ConvPool(256,512,3,2,2,3,act='relu')
        self.hidden5=ConvPool(512,512,3,2,2,3,act='relu')
        self.hidden6=fluid.dygraph.Linear(512*5*5,4096,act='relu')
        self.hidden7=fluid.dygraph.Linear(4096,4096,act='relu')
        self.hidden8=fluid.dygraph.Linear(4096,2,act='softmax')

    def forward(self, inputs, label=None):
        """前向计算"""
        # print(inputs.shape)         #[8, 3, 224, 224]
        x=self.hidden1(inputs)
        # print(x.shape)              #[8, 64, 111, 111]
        x=self.hidden2(x)
        # print(x.shape)              #[8, 128, 54, 54]
        x=self.hidden3(x)
        # print(x.shape)              #[8, 256, 26, 26]
        x=self.hidden4(x)
        # print(x.shape)              #[8, 512, 12, 12]
        x=self.hidden5(x)
        # print(x.shape)              #[8, 512, 5, 5]
        x=fluid.layers.reshape(x,shape=[-1,512*5*5])
        # print(x.shape)              #[8, 12800]
        x=self.hidden6(x)
        # print(x.shape)              #[8, 4096]
        x=self.hidden7(x)
        # print(x.shape)              #[8, 4096]
        y=self.hidden8(x)
        # print(y.shape)              #[8, 2]  

        return y, fluid.layers.accuracy(input=y,label=label)

# %% [markdown]
# # **三、模型训练 && 四、模型评估**

# %%
all_train_iter=0
all_train_iters=[]
all_train_costs=[]
all_train_accs=[]

def draw_train_process(title,iters,costs,accs,label_cost,lable_acc):
    plt.title(title, fontsize=24)
    plt.xlabel("iter", fontsize=20)
    plt.ylabel("cost/acc", fontsize=20)
    plt.plot(iters, costs,color='red',label=label_cost) 
    plt.plot(iters, accs,color='green',label=lable_acc) 
    plt.legend()
    plt.grid()
    plt.show()


def draw_process(title,color,iters,data,label):
    plt.title(title, fontsize=24)
    plt.xlabel("iter", fontsize=20)
    plt.ylabel(label, fontsize=20)
    plt.plot(iters, data,color=color,label=label) 
    plt.legend()
    plt.grid()
    plt.show()

# %%
'''
模型训练
'''
#with fluid.dygraph.guard(place = fluid.CUDAPlace(0)):
with fluid.dygraph.guard():
    print(train_parameters['class_dim'])
    print(train_parameters['label_dict'])
    vgg = VGGNet()
    optimizer=fluid.optimizer.AdamOptimizer(learning_rate=train_parameters['learning_strategy']['lr'],parameter_list=vgg.parameters()) 
    for epoch_num in range(train_parameters['num_epochs']):
        for batch_id, data in enumerate(train_reader()):
            dy_x_data = np.array([x[0] for x in data]).astype('float32')           
            y_data = np.array([x[1] for x in data]).astype('int64')      
            y_data = y_data[:, np.newaxis]

            #将Numpy转换为DyGraph接收的输入
            img = fluid.dygraph.to_variable(dy_x_data)
            label = fluid.dygraph.to_variable(y_data)

            out,acc = vgg(img,label)
            loss = fluid.layers.cross_entropy(out, label)
            avg_loss = fluid.layers.mean(loss)

            #使用backward()方法可以执行反向网络
            avg_loss.backward()
            optimizer.minimize(avg_loss)
            
            #将参数梯度清零以保证下一轮训练的正确性
            vgg.clear_gradients()
            

            all_train_iter=all_train_iter+train_parameters['train_batch_size']
            all_train_iters.append(all_train_iter)
            all_train_costs.append(loss.numpy()[0])
            all_train_accs.append(acc.numpy()[0])
                
            if batch_id % 1 == 0:
                print("Loss at epoch {} step {}: {}, acc: {}".format(epoch_num, batch_id, avg_loss.numpy(), acc.numpy()))

    draw_train_process("training",all_train_iters,all_train_costs,all_train_accs,"trainning cost","trainning acc")  
    draw_process("trainning loss","red",all_train_iters,all_train_costs,"trainning loss")
    draw_process("trainning acc","green",all_train_iters,all_train_accs,"trainning acc")  
    
    #保存模型参数
    fluid.save_dygraph(vgg.state_dict(), "vgg")   
    print("Final loss: {}".format(avg_loss.numpy()))
# Out:
# 2
# {'0': 'nomaskimages', '1': 'maskimages'}
# Loss at epoch 0 step 0: [0.8879887], acc: [0.5]
# Loss at epoch 0 step 1: [32.], acc: [0.5]
# Loss at epoch 0 step 2: [10.070547], acc: [0.625]
# Loss at epoch 0 step 3: [0.69604063], acc: [0.5]
# Loss at epoch 0 step 4: [3.6651075], acc: [0.25]
# Loss at epoch 0 step 5: [1.7969458], acc: [0.125]
# Loss at epoch 0 step 6: [0.39881635], acc: [0.875]
# Loss at epoch 0 step 7: [1.8912053], acc: [0.5]
# Loss at epoch 0 step 8: [1.1248678], acc: [0.5]
# Loss at epoch 0 step 9: [0.69261384], acc: [0.5]
# Loss at epoch 0 step 10: [0.92419904], acc: [0.25]
# Loss at epoch 0 step 11: [0.89754415], acc: [0.125]
# Loss at epoch 0 step 12: [0.71702707], acc: [0.375]
# Loss at epoch 0 step 13: [0.6908263], acc: [0.625]
# Loss at epoch 0 step 14: [0.67268634], acc: [0.625]
# Loss at epoch 0 step 15: [0.5500781], acc: [0.875]
# Loss at epoch 0 step 16: [1.1998565], acc: [0.375]
# Loss at epoch 0 step 17: [0.6440362], acc: [0.625]
# Loss at epoch 0 step 18: [0.5166707], acc: [0.875]
# Loss at epoch 0 step 19: [0.6440348], acc: [0.625]
# Loss at epoch 1 step 0: [0.78883034], acc: [0.5]
# Loss at epoch 1 step 1: [0.7322063], acc: [0.5]
# Loss at epoch 1 step 2: [0.64736766], acc: [0.625]
# Loss at epoch 1 step 3: [0.68534255], acc: [0.5]
# Loss at epoch 1 step 4: [0.71703833], acc: [0.25]
# Loss at epoch 1 step 5: [0.6971103], acc: [0.25]
# Loss at epoch 1 step 6: [0.6923757], acc: [0.375]
# Loss at epoch 1 step 7: [0.68686116], acc: [0.5]
# Loss at epoch 1 step 8: [0.68676627], acc: [0.5]
# Loss at epoch 1 step 9: [0.68498254], acc: [0.5]
# Loss at epoch 1 step 10: [0.6417905], acc: [0.75]
# Loss at epoch 1 step 11: [0.5548278], acc: [0.875]
# Loss at epoch 1 step 12: [0.63655365], acc: [0.625]
# Loss at epoch 1 step 13: [0.6997545], acc: [0.625]
# Loss at epoch 1 step 14: [0.6462147], acc: [0.625]
# Loss at epoch 1 step 15: [0.51775765], acc: [0.875]
# Loss at epoch 1 step 16: [0.7551961], acc: [0.375]
# Loss at epoch 1 step 17: [0.62453485], acc: [0.625]
# Loss at epoch 1 step 18: [0.5492395], acc: [0.875]
# Loss at epoch 1 step 19: [0.6399324], acc: [0.625]
# Loss at epoch 2 step 0: [0.71123636], acc: [0.5]
# Loss at epoch 2 step 1: [0.68429047], acc: [0.5]
# Loss at epoch 2 step 2: [0.58524275], acc: [0.625]
# Loss at epoch 2 step 3: [0.581625], acc: [0.5]
# Loss at epoch 2 step 4: [0.8661883], acc: [0.25]
# Loss at epoch 2 step 5: [0.55420035], acc: [0.875]
# Loss at epoch 2 step 6: [0.5742708], acc: [0.875]
# Loss at epoch 2 step 7: [0.627694], acc: [0.5]
# Loss at epoch 2 step 8: [0.5991347], acc: [0.5]
# Loss at epoch 2 step 9: [0.55416495], acc: [0.5]
# Loss at epoch 2 step 10: [0.53274447], acc: [0.75]
# Loss at epoch 2 step 11: [0.32991925], acc: [0.875]
# Loss at epoch 2 step 12: [0.47114816], acc: [0.625]
# Loss at epoch 2 step 13: [0.42480165], acc: [0.75]
# Loss at epoch 2 step 14: [0.56853604], acc: [0.625]
# Loss at epoch 2 step 15: [0.42689496], acc: [1.]
# Loss at epoch 2 step 16: [0.6739305], acc: [0.75]
# Loss at epoch 2 step 17: [0.59872514], acc: [0.875]
# Loss at epoch 2 step 18: [0.63927233], acc: [0.5]
# Loss at epoch 2 step 19: [0.66878295], acc: [0.75]
# Loss at epoch 3 step 0: [0.60940874], acc: [0.625]
# Loss at epoch 3 step 1: [0.34971902], acc: [0.875]
# Loss at epoch 3 step 2: [0.19166538], acc: [0.875]
# Loss at epoch 3 step 3: [0.8652512], acc: [0.75]
# Loss at epoch 3 step 4: [0.33051583], acc: [0.875]
# Loss at epoch 3 step 5: [0.6478162], acc: [0.75]
# Loss at epoch 3 step 6: [0.58350676], acc: [0.375]
# Loss at epoch 3 step 7: [0.7156838], acc: [0.625]
# Loss at epoch 3 step 8: [0.6356502], acc: [0.625]
# Loss at epoch 3 step 9: [0.8080784], acc: [0.625]
# Loss at epoch 3 step 10: [0.6630574], acc: [0.5]
# Loss at epoch 3 step 11: [0.682771], acc: [0.75]
# Loss at epoch 3 step 12: [0.65193886], acc: [0.625]
# Loss at epoch 3 step 13: [0.6740673], acc: [0.625]
# Loss at epoch 3 step 14: [0.65652734], acc: [0.625]
# Loss at epoch 3 step 15: [0.5472259], acc: [1.]
# Loss at epoch 3 step 16: [1.1719433], acc: [0.375]
# Loss at epoch 3 step 17: [0.65140355], acc: [0.625]
# Loss at epoch 3 step 18: [0.47970867], acc: [0.875]
# Loss at epoch 3 step 19: [0.6427686], acc: [0.625]
# Loss at epoch 4 step 0: [0.68069386], acc: [0.5]
# Loss at epoch 4 step 1: [0.65560454], acc: [0.5]
# Loss at epoch 4 step 2: [0.6083561], acc: [0.75]
# Loss at epoch 4 step 3: [0.61485195], acc: [0.5]
# Loss at epoch 4 step 4: [0.7720407], acc: [0.25]
# Loss at epoch 4 step 5: [0.52620935], acc: [0.875]
# Loss at epoch 4 step 6: [0.4760802], acc: [0.875]
# Loss at epoch 4 step 7: [0.6033757], acc: [0.5]
# Loss at epoch 4 step 8: [0.6009478], acc: [0.5]
# Loss at epoch 4 step 9: [0.5596937], acc: [0.5]
# Loss at epoch 4 step 10: [0.41791058], acc: [1.]
# Loss at epoch 4 step 11: [0.26914656], acc: [0.875]
# Loss at epoch 4 step 12: [0.64878595], acc: [0.625]
# Loss at epoch 4 step 13: [0.40791133], acc: [0.875]
# Loss at epoch 4 step 14: [0.36126104], acc: [0.875]
# Loss at epoch 4 step 15: [0.6239779], acc: [0.625]
# Loss at epoch 4 step 16: [0.5611931], acc: [0.625]
# Loss at epoch 4 step 17: [0.4473379], acc: [0.875]
# Loss at epoch 4 step 18: [0.2585538], acc: [0.875]
# Loss at epoch 4 step 19: [0.34150532], acc: [0.875]
# Loss at epoch 5 step 0: [0.23515934], acc: [0.875]
# Loss at epoch 5 step 1: [0.36658013], acc: [0.875]
# Loss at epoch 5 step 2: [0.08717443], acc: [1.]
# Loss at epoch 5 step 3: [1.572701], acc: [0.75]
# Loss at epoch 5 step 4: [1.0189512], acc: [0.75]
# Loss at epoch 5 step 5: [0.9587984], acc: [0.625]
# Loss at epoch 5 step 6: [1.437268], acc: [0.25]
# Loss at epoch 5 step 7: [0.71045995], acc: [0.5]
# Loss at epoch 5 step 8: [0.61693966], acc: [0.875]
# Loss at epoch 5 step 9: [0.75016606], acc: [0.375]
# Loss at epoch 5 step 10: [0.59769154], acc: [0.5]
# Loss at epoch 5 step 11: [0.6801398], acc: [0.75]
# Loss at epoch 5 step 12: [0.7397709], acc: [0.625]
# Loss at epoch 5 step 13: [0.7086482], acc: [0.625]
# Loss at epoch 5 step 14: [0.5919709], acc: [0.625]
# Loss at epoch 5 step 15: [0.5363748], acc: [0.875]
# Loss at epoch 5 step 16: [0.73678267], acc: [0.375]
# Loss at epoch 5 step 17: [0.61315197], acc: [0.625]
# Loss at epoch 5 step 18: [0.39010587], acc: [0.875]
# Loss at epoch 5 step 19: [0.86016095], acc: [0.625]
# Loss at epoch 6 step 0: [0.8299177], acc: [0.5]
# Loss at epoch 6 step 1: [0.6221394], acc: [0.625]
# Loss at epoch 6 step 2: [0.60312724], acc: [0.75]
# Loss at epoch 6 step 3: [0.65483797], acc: [0.5]
# Loss at epoch 6 step 4: [0.6881145], acc: [0.375]
# Loss at epoch 6 step 5: [0.61143196], acc: [0.75]
# Loss at epoch 6 step 6: [0.4865647], acc: [1.]
# Loss at epoch 6 step 7: [0.7627763], acc: [0.5]
# Loss at epoch 6 step 8: [0.69020975], acc: [0.5]
# Loss at epoch 6 step 9: [0.6026124], acc: [0.375]
# Loss at epoch 6 step 10: [0.6242295], acc: [0.375]
# Loss at epoch 6 step 11: [0.6572206], acc: [0.625]
# Loss at epoch 6 step 12: [0.5116174], acc: [0.625]
# Loss at epoch 6 step 13: [0.62556076], acc: [0.625]
# Loss at epoch 6 step 14: [0.49871594], acc: [0.625]
# Loss at epoch 6 step 15: [0.34865725], acc: [0.875]
# Loss at epoch 6 step 16: [0.6024561], acc: [0.75]
# Loss at epoch 6 step 17: [0.49682355], acc: [0.875]
# Loss at epoch 6 step 18: [0.5551073], acc: [0.5]
# Loss at epoch 6 step 19: [0.4545399], acc: [0.875]
# Loss at epoch 7 step 0: [0.46231157], acc: [0.75]
# Loss at epoch 7 step 1: [0.06663295], acc: [1.]
# Loss at epoch 7 step 2: [0.00441843], acc: [1.]
# Loss at epoch 7 step 3: [0.94253427], acc: [0.75]
# Loss at epoch 7 step 4: [0.03014824], acc: [1.]
# Loss at epoch 7 step 5: [1.1085664], acc: [0.75]
# Loss at epoch 7 step 6: [0.33256668], acc: [1.]
# Loss at epoch 7 step 7: [0.36770827], acc: [0.875]
# Loss at epoch 7 step 8: [0.40740156], acc: [0.875]
# Loss at epoch 7 step 9: [0.45799482], acc: [0.75]
# Loss at epoch 7 step 10: [0.23511605], acc: [1.]
# Loss at epoch 7 step 11: [0.1944128], acc: [0.875]
# Loss at epoch 7 step 12: [1.0210052], acc: [0.625]
# Loss at epoch 7 step 13: [0.3298312], acc: [0.875]
# Loss at epoch 7 step 14: [0.1762161], acc: [0.875]
# Loss at epoch 7 step 15: [1.9807396], acc: [0.375]
# Loss at epoch 7 step 16: [0.56512], acc: [0.75]
# Loss at epoch 7 step 17: [0.18284355], acc: [1.]
# Loss at epoch 7 step 18: [0.23500341], acc: [0.875]
# Loss at epoch 7 step 19: [0.93717766], acc: [0.625]
# Loss at epoch 8 step 0: [0.40105152], acc: [0.75]
# Loss at epoch 8 step 1: [0.24238062], acc: [1.]
# Loss at epoch 8 step 2: [0.4917056], acc: [0.625]
# Loss at epoch 8 step 3: [0.38580132], acc: [0.875]
# Loss at epoch 8 step 4: [0.31718284], acc: [0.875]
# Loss at epoch 8 step 5: [0.08006442], acc: [1.]
# Loss at epoch 8 step 6: [0.11664185], acc: [0.875]
# Loss at epoch 8 step 7: [0.33165768], acc: [0.875]
# Loss at epoch 8 step 8: [0.28150046], acc: [0.75]
# Loss at epoch 8 step 9: [0.12791069], acc: [1.]
# Loss at epoch 8 step 10: [0.5738866], acc: [0.875]
# Loss at epoch 8 step 11: [0.07622448], acc: [1.]
# Loss at epoch 8 step 12: [0.26237118], acc: [0.75]
# Loss at epoch 8 step 13: [0.42898872], acc: [0.875]
# Loss at epoch 8 step 14: [0.46657962], acc: [0.75]
# Loss at epoch 8 step 15: [0.6097081], acc: [0.75]
# Loss at epoch 8 step 16: [0.63432467], acc: [0.625]
# Loss at epoch 8 step 17: [0.7653247], acc: [0.5]
# Loss at epoch 8 step 18: [0.68036586], acc: [0.25]
# Loss at epoch 8 step 19: [0.54301274], acc: [0.75]
# Loss at epoch 9 step 0: [2.007854], acc: [0.5]
# Loss at epoch 9 step 1: [0.57812655], acc: [0.625]
# Loss at epoch 9 step 2: [0.6520897], acc: [0.625]
# Loss at epoch 9 step 3: [0.62646866], acc: [0.75]
# Loss at epoch 9 step 4: [0.6949333], acc: [0.625]
# Loss at epoch 9 step 5: [0.564198], acc: [0.875]
# Loss at epoch 9 step 6: [0.57824355], acc: [0.625]
# Loss at epoch 9 step 7: [0.64185405], acc: [0.75]
# Loss at epoch 9 step 8: [0.60093963], acc: [0.5]
# Loss at epoch 9 step 9: [0.5745022], acc: [0.5]
# Loss at epoch 9 step 10: [0.48729813], acc: [0.75]
# Loss at epoch 9 step 11: [0.58840466], acc: [0.75]
# Loss at epoch 9 step 12: [0.6861577], acc: [0.625]
# Loss at epoch 9 step 13: [0.70549035], acc: [0.625]
# Loss at epoch 9 step 14: [0.39839837], acc: [0.625]
# Loss at epoch 9 step 15: [0.29310966], acc: [0.875]
# Loss at epoch 9 step 16: [0.54389155], acc: [0.75]
# Loss at epoch 9 step 17: [0.42660737], acc: [0.75]
# Loss at epoch 9 step 18: [0.44784823], acc: [0.75]
# Loss at epoch 9 step 19: [0.73372936], acc: [0.625]
# Loss at epoch 10 step 0: [0.74670273], acc: [0.625]
# Loss at epoch 10 step 1: [0.29644227], acc: [1.]
# Loss at epoch 10 step 2: [0.29178464], acc: [0.875]
# Loss at epoch 10 step 3: [0.4215933], acc: [0.75]
# Loss at epoch 10 step 4: [0.7408136], acc: [0.375]
# Loss at epoch 10 step 5: [0.29224607], acc: [0.875]
# Loss at epoch 10 step 6: [0.34558487], acc: [0.875]
# Loss at epoch 10 step 7: [0.26305577], acc: [0.875]
# Loss at epoch 10 step 8: [0.1608236], acc: [1.]
# Loss at epoch 10 step 9: [0.19063744], acc: [1.]
# Loss at epoch 10 step 10: [0.09557313], acc: [0.875]
# Loss at epoch 10 step 11: [0.20298544], acc: [0.875]
# Loss at epoch 10 step 12: [0.00315633], acc: [1.]
# Loss at epoch 10 step 13: [0.48760194], acc: [0.875]
# Loss at epoch 10 step 14: [0.43808135], acc: [0.875]
# Loss at epoch 10 step 15: [0.5359872], acc: [0.5]
# Loss at epoch 10 step 16: [0.35178173], acc: [0.875]
# Loss at epoch 10 step 17: [0.6167224], acc: [0.875]
# Loss at epoch 10 step 18: [0.6373757], acc: [0.375]
# Loss at epoch 10 step 19: [0.49583605], acc: [0.875]
# Loss at epoch 11 step 0: [0.44518685], acc: [0.75]
# Loss at epoch 11 step 1: [0.20370486], acc: [1.]
# Loss at epoch 11 step 2: [0.13275915], acc: [1.]
# Loss at epoch 11 step 3: [0.29797238], acc: [0.875]
# Loss at epoch 11 step 4: [0.96902835], acc: [0.75]
# Loss at epoch 11 step 5: [0.09233639], acc: [0.875]
# Loss at epoch 11 step 6: [0.05878415], acc: [1.]
# Loss at epoch 11 step 7: [0.3503634], acc: [0.875]
# Loss at epoch 11 step 8: [0.3147868], acc: [1.]
# Loss at epoch 11 step 9: [0.39699075], acc: [0.875]
# Loss at epoch 11 step 10: [0.36345482], acc: [0.75]
# Loss at epoch 11 step 11: [0.47535858], acc: [0.875]
# Loss at epoch 11 step 12: [0.35957614], acc: [0.875]
# Loss at epoch 11 step 13: [0.34231493], acc: [0.875]
# Loss at epoch 11 step 14: [2.378578], acc: [0.625]
# Loss at epoch 11 step 15: [0.16935603], acc: [0.875]
# Loss at epoch 11 step 16: [0.36807045], acc: [0.875]
# Loss at epoch 11 step 17: [0.14866973], acc: [1.]
# Loss at epoch 11 step 18: [0.21147874], acc: [1.]
# Loss at epoch 11 step 19: [0.6341054], acc: [0.75]
# Loss at epoch 12 step 0: [0.23601094], acc: [1.]
# Loss at epoch 12 step 1: [0.23624796], acc: [1.]
# Loss at epoch 12 step 2: [0.48777208], acc: [0.875]
# Loss at epoch 12 step 3: [0.16362348], acc: [1.]
# Loss at epoch 12 step 4: [0.24542603], acc: [1.]
# Loss at epoch 12 step 5: [0.1032588], acc: [1.]
# Loss at epoch 12 step 6: [0.07947617], acc: [1.]
# Loss at epoch 12 step 7: [0.2051515], acc: [0.875]
# Loss at epoch 12 step 8: [0.05806551], acc: [1.]
# Loss at epoch 12 step 9: [0.00789401], acc: [1.]
# Loss at epoch 12 step 10: [0.01004313], acc: [1.]
# Loss at epoch 12 step 11: [0.009147], acc: [1.]
# Loss at epoch 12 step 12: [0.00023576], acc: [1.]
# Loss at epoch 12 step 13: [0.3750893], acc: [0.875]
# Loss at epoch 12 step 14: [0.50198066], acc: [0.75]
# Loss at epoch 12 step 15: [0.00571582], acc: [1.]
# Loss at epoch 12 step 16: [3.6923351], acc: [0.875]
# Loss at epoch 12 step 17: [0.01050405], acc: [1.]
# Loss at epoch 12 step 18: [0.06668369], acc: [1.]
# Loss at epoch 12 step 19: [0.7612464], acc: [0.75]
# Loss at epoch 13 step 0: [0.33237576], acc: [0.75]
# Loss at epoch 13 step 1: [0.05665039], acc: [1.]
# Loss at epoch 13 step 2: [0.08344749], acc: [1.]
# Loss at epoch 13 step 3: [0.21395993], acc: [1.]
# Loss at epoch 13 step 4: [0.26935935], acc: [0.875]
# Loss at epoch 13 step 5: [0.08416718], acc: [1.]
# Loss at epoch 13 step 6: [0.06156125], acc: [1.]
# Loss at epoch 13 step 7: [0.18124168], acc: [0.875]
# Loss at epoch 13 step 8: [0.12017745], acc: [0.875]
# Loss at epoch 13 step 9: [0.06176319], acc: [1.]
# Loss at epoch 13 step 10: [0.00115427], acc: [1.]
# Loss at epoch 13 step 11: [0.00156881], acc: [1.]
# Loss at epoch 13 step 12: [7.5437056e-05], acc: [1.]
# Loss at epoch 13 step 13: [0.4796148], acc: [0.875]
# Loss at epoch 13 step 14: [0.4994649], acc: [0.75]
# Loss at epoch 13 step 15: [6.1471243], acc: [0.25]
# Loss at epoch 13 step 16: [1.9007022], acc: [0.875]
# Loss at epoch 13 step 17: [0.0478246], acc: [1.]
# Loss at epoch 13 step 18: [0.04063351], acc: [1.]
# Loss at epoch 13 step 19: [1.017056], acc: [0.625]
# Loss at epoch 14 step 0: [0.6141764], acc: [0.625]
# Loss at epoch 14 step 1: [0.11682053], acc: [1.]
# Loss at epoch 14 step 2: [0.27526182], acc: [1.]
# Loss at epoch 14 step 3: [0.2967357], acc: [0.875]
# Loss at epoch 14 step 4: [0.36645418], acc: [0.875]
# Loss at epoch 14 step 5: [0.2600764], acc: [0.875]
# Loss at epoch 14 step 6: [0.25275418], acc: [0.875]
# Loss at epoch 14 step 7: [0.2813771], acc: [0.875]
# Loss at epoch 14 step 8: [0.19112039], acc: [1.]
# Loss at epoch 14 step 9: [0.3376965], acc: [0.75]
# Loss at epoch 14 step 10: [0.28883967], acc: [0.875]
# Loss at epoch 14 step 11: [0.08705272], acc: [1.]
# Loss at epoch 14 step 12: [0.03287155], acc: [1.]
# Loss at epoch 14 step 13: [0.3906498], acc: [0.875]
# Loss at epoch 14 step 14: [0.87681735], acc: [0.75]
# Loss at epoch 14 step 15: [0.05410339], acc: [1.]
# Loss at epoch 14 step 16: [0.3653289], acc: [0.75]
# Loss at epoch 14 step 17: [1.2436311], acc: [0.5]
# Loss at epoch 14 step 18: [0.77957106], acc: [0.375]
# Loss at epoch 14 step 19: [0.6117602], acc: [0.75]
# Loss at epoch 15 step 0: [0.74743044], acc: [0.375]
# Loss at epoch 15 step 1: [0.42527923], acc: [0.875]
# Loss at epoch 15 step 2: [0.6679378], acc: [0.625]
# Loss at epoch 15 step 3: [0.7098272], acc: [0.375]
# Loss at epoch 15 step 4: [0.75650966], acc: [0.25]
# Loss at epoch 15 step 5: [0.8470678], acc: [0.25]
# Loss at epoch 15 step 6: [0.68806976], acc: [0.25]
# Loss at epoch 15 step 7: [0.65939325], acc: [0.625]
# Loss at epoch 15 step 8: [0.7086588], acc: [0.5]
# Loss at epoch 15 step 9: [0.62672657], acc: [0.625]
# Loss at epoch 15 step 10: [0.51682836], acc: [0.75]
# Loss at epoch 15 step 11: [0.39032024], acc: [0.875]
# Loss at epoch 15 step 12: [0.83666754], acc: [0.625]
# Loss at epoch 15 step 13: [0.64153516], acc: [0.625]
# Loss at epoch 15 step 14: [0.5208337], acc: [0.625]
# Loss at epoch 15 step 15: [0.41372815], acc: [0.875]
# Loss at epoch 15 step 16: [0.5736872], acc: [0.75]
# Loss at epoch 15 step 17: [0.55324244], acc: [0.75]
# Loss at epoch 15 step 18: [0.44578767], acc: [0.875]
# Loss at epoch 15 step 19: [0.5816711], acc: [0.75]
# Loss at epoch 16 step 0: [1.0070311], acc: [0.5]
# Loss at epoch 16 step 1: [0.15236041], acc: [1.]
# Loss at epoch 16 step 2: [0.44112402], acc: [0.625]
# Loss at epoch 16 step 3: [0.42413783], acc: [0.75]
# Loss at epoch 16 step 4: [0.50619894], acc: [0.75]
# Loss at epoch 16 step 5: [0.33356208], acc: [0.875]
# Loss at epoch 16 step 6: [0.48803702], acc: [0.625]
# Loss at epoch 16 step 7: [0.40323383], acc: [0.875]
# Loss at epoch 16 step 8: [0.4407019], acc: [0.75]
# Loss at epoch 16 step 9: [0.23986006], acc: [0.875]
# Loss at epoch 16 step 10: [0.13612266], acc: [1.]
# Loss at epoch 16 step 11: [0.08752631], acc: [1.]
# Loss at epoch 16 step 12: [1.7541537], acc: [0.75]
# Loss at epoch 16 step 13: [0.12442049], acc: [1.]
# Loss at epoch 16 step 14: [0.53364474], acc: [0.75]
# Loss at epoch 16 step 15: [0.07737579], acc: [1.]
# Loss at epoch 16 step 16: [0.3895233], acc: [0.875]
# Loss at epoch 16 step 17: [0.3719202], acc: [0.875]
# Loss at epoch 16 step 18: [0.5003064], acc: [0.75]
# Loss at epoch 16 step 19: [0.5446174], acc: [0.625]
# Loss at epoch 17 step 0: [0.86875004], acc: [0.5]
# Loss at epoch 17 step 1: [0.16493827], acc: [1.]
# Loss at epoch 17 step 2: [0.29141137], acc: [0.875]
# Loss at epoch 17 step 3: [0.4045533], acc: [0.625]
# Loss at epoch 17 step 4: [0.669449], acc: [0.5]
# Loss at epoch 17 step 5: [0.19285618], acc: [0.875]
# Loss at epoch 17 step 6: [0.23585041], acc: [1.]
# Loss at epoch 17 step 7: [0.22262053], acc: [0.875]
# Loss at epoch 17 step 8: [0.16442701], acc: [1.]
# Loss at epoch 17 step 9: [0.14083429], acc: [1.]
# Loss at epoch 17 step 10: [0.02754829], acc: [1.]
# Loss at epoch 17 step 11: [0.01653994], acc: [1.]
# Loss at epoch 17 step 12: [0.00061166], acc: [1.]
# Loss at epoch 17 step 13: [0.07895169], acc: [1.]
# Loss at epoch 17 step 14: [0.26352108], acc: [0.875]
# Loss at epoch 17 step 15: [0.38835526], acc: [0.875]
# Loss at epoch 17 step 16: [3.4771852], acc: [0.875]
# Loss at epoch 17 step 17: [1.5572426e-05], acc: [1.]
# Loss at epoch 17 step 18: [0.6353752], acc: [0.875]
# Loss at epoch 17 step 19: [1.009811], acc: [0.75]
# Loss at epoch 18 step 0: [0.6347725], acc: [0.75]
# Loss at epoch 18 step 1: [0.03625404], acc: [1.]
# Loss at epoch 18 step 2: [0.06449781], acc: [1.]
# Loss at epoch 18 step 3: [0.2542567], acc: [0.875]
# Loss at epoch 18 step 4: [0.31419516], acc: [1.]
# Loss at epoch 18 step 5: [0.14203116], acc: [1.]
# Loss at epoch 18 step 6: [0.21116954], acc: [1.]
# Loss at epoch 18 step 7: [0.26432732], acc: [0.875]
# Loss at epoch 18 step 8: [0.21481012], acc: [1.]
# Loss at epoch 18 step 9: [0.2351154], acc: [0.875]
# Loss at epoch 18 step 10: [0.06034861], acc: [1.]
# Loss at epoch 18 step 11: [0.03364754], acc: [1.]
# Loss at epoch 18 step 12: [0.01099941], acc: [1.]
# Loss at epoch 18 step 13: [0.00636942], acc: [1.]
# Loss at epoch 18 step 14: [0.3706332], acc: [0.875]
# Loss at epoch 18 step 15: [19.293346], acc: [0.375]
# Loss at epoch 18 step 16: [0.33498588], acc: [0.875]
# Loss at epoch 18 step 17: [1.5965053], acc: [0.75]
# Loss at epoch 18 step 18: [3.1140523], acc: [0.875]
# Loss at epoch 18 step 19: [3.2535253], acc: [0.625]
# Loss at epoch 19 step 0: [0.4874823], acc: [0.75]
# Loss at epoch 19 step 1: [2.8388505], acc: [0.5]
# Loss at epoch 19 step 2: [2.32581], acc: [0.5]
# Loss at epoch 19 step 3: [0.63099027], acc: [0.625]
# Loss at epoch 19 step 4: [2.5548222], acc: [0.375]
# Loss at epoch 19 step 5: [0.03587685], acc: [1.]
# Loss at epoch 19 step 6: [0.2883734], acc: [0.875]
# Loss at epoch 19 step 7: [0.6384361], acc: [0.625]
# Loss at epoch 19 step 8: [0.48932898], acc: [0.75]
# Loss at epoch 19 step 9: [0.65826476], acc: [0.625]
# Loss at epoch 19 step 10: [0.43418548], acc: [0.875]
# Loss at epoch 19 step 11: [0.3011164], acc: [0.875]
# Loss at epoch 19 step 12: [0.6508434], acc: [0.625]
# Loss at epoch 19 step 13: [0.68637013], acc: [0.625]
# Loss at epoch 19 step 14: [0.90838385], acc: [0.625]
# Loss at epoch 19 step 15: [0.17051336], acc: [0.875]
# Loss at epoch 19 step 16: [0.49264956], acc: [0.625]
# Loss at epoch 19 step 17: [0.4156801], acc: [0.75]
# Loss at epoch 19 step 18: [0.4657843], acc: [0.875]
# Loss at epoch 19 step 19: [0.42211387], acc: [0.875]
# Loss at epoch 20 step 0: [0.50332904], acc: [0.625]
# Loss at epoch 20 step 1: [0.12315364], acc: [1.]
# Loss at epoch 20 step 2: [0.09604426], acc: [1.]
# Loss at epoch 20 step 3: [0.35579422], acc: [0.75]
# Loss at epoch 20 step 4: [0.5386807], acc: [0.75]
# Loss at epoch 20 step 5: [0.03167988], acc: [1.]
# Loss at epoch 20 step 6: [0.25060856], acc: [0.875]
# Loss at epoch 20 step 7: [0.43451864], acc: [0.875]
# Loss at epoch 20 step 8: [0.07119138], acc: [1.]
# Loss at epoch 20 step 9: [0.11322748], acc: [1.]
# Loss at epoch 20 step 10: [0.1668035], acc: [0.875]
# Loss at epoch 20 step 11: [0.14773026], acc: [0.875]
# Loss at epoch 20 step 12: [0.21052924], acc: [0.875]
# Loss at epoch 20 step 13: [0.25305757], acc: [0.875]
# Loss at epoch 20 step 14: [0.8214383], acc: [0.875]
# Loss at epoch 20 step 15: [0.00250138], acc: [1.]
# Loss at epoch 20 step 16: [0.587502], acc: [0.875]
# Loss at epoch 20 step 17: [0.31299797], acc: [0.875]
# Loss at epoch 20 step 18: [0.6125876], acc: [0.625]
# Loss at epoch 20 step 19: [0.4328181], acc: [0.875]
# Loss at epoch 21 step 0: [0.6193328], acc: [0.75]
# Loss at epoch 21 step 1: [0.11657], acc: [1.]
# Loss at epoch 21 step 2: [0.34532377], acc: [0.75]
# Loss at epoch 21 step 3: [0.5035558], acc: [0.625]
# Loss at epoch 21 step 4: [0.7668654], acc: [0.5]
# Loss at epoch 21 step 5: [0.12065572], acc: [1.]
# Loss at epoch 21 step 6: [0.196678], acc: [1.]
# Loss at epoch 21 step 7: [0.31435168], acc: [0.875]
# Loss at epoch 21 step 8: [0.2374], acc: [1.]
# Loss at epoch 21 step 9: [0.46093985], acc: [0.625]
# Loss at epoch 21 step 10: [0.03429196], acc: [1.]
# Loss at epoch 21 step 11: [0.14992703], acc: [0.875]
# Loss at epoch 21 step 12: [0.07157827], acc: [1.]
# Loss at epoch 21 step 13: [0.14352006], acc: [1.]
# Loss at epoch 21 step 14: [1.1858069], acc: [0.75]
# Loss at epoch 21 step 15: [0.00026955], acc: [1.]
# Loss at epoch 21 step 16: [0.9830245], acc: [0.875]
# Loss at epoch 21 step 17: [0.5346966], acc: [0.875]
# Loss at epoch 21 step 18: [0.56650466], acc: [0.625]
# Loss at epoch 21 step 19: [0.41995046], acc: [0.875]
# Loss at epoch 22 step 0: [0.28757867], acc: [1.]
# Loss at epoch 22 step 1: [0.11276796], acc: [1.]
# Loss at epoch 22 step 2: [0.05435336], acc: [1.]
# Loss at epoch 22 step 3: [0.2347608], acc: [1.]
# Loss at epoch 22 step 4: [0.5106233], acc: [0.75]
# Loss at epoch 22 step 5: [0.05068204], acc: [1.]
# Loss at epoch 22 step 6: [0.03923055], acc: [1.]
# Loss at epoch 22 step 7: [0.5587755], acc: [0.875]
# Loss at epoch 22 step 8: [0.17529765], acc: [1.]
# Loss at epoch 22 step 9: [0.23096666], acc: [1.]
# Loss at epoch 22 step 10: [0.04010841], acc: [1.]
# Loss at epoch 22 step 11: [0.23220497], acc: [1.]
# Loss at epoch 22 step 12: [0.03152371], acc: [1.]
# Loss at epoch 22 step 13: [0.03051183], acc: [1.]
# Loss at epoch 22 step 14: [0.6346617], acc: [0.875]
# Loss at epoch 22 step 15: [0.00010808], acc: [1.]
# Loss at epoch 22 step 16: [0.9265621], acc: [0.875]
# Loss at epoch 22 step 17: [0.01221933], acc: [1.]
# Loss at epoch 22 step 18: [0.02765487], acc: [1.]
# Loss at epoch 22 step 19: [0.51315], acc: [0.875]
# Loss at epoch 23 step 0: [0.23674425], acc: [0.875]
# Loss at epoch 23 step 1: [0.01309267], acc: [1.]
# Loss at epoch 23 step 2: [0.00495542], acc: [1.]
# Loss at epoch 23 step 3: [0.27243987], acc: [0.875]
# Loss at epoch 23 step 4: [0.35056296], acc: [0.75]
# Loss at epoch 23 step 5: [0.01631016], acc: [1.]
# Loss at epoch 23 step 6: [0.09386224], acc: [1.]
# Loss at epoch 23 step 7: [0.16737999], acc: [0.875]
# Loss at epoch 23 step 8: [0.10962997], acc: [1.]
# Loss at epoch 23 step 9: [0.18472351], acc: [1.]
# Loss at epoch 23 step 10: [0.01062226], acc: [1.]
# Loss at epoch 23 step 11: [0.0680811], acc: [1.]
# Loss at epoch 23 step 12: [0.02758608], acc: [1.]
# Loss at epoch 23 step 13: [0.0247069], acc: [1.]
# Loss at epoch 23 step 14: [0.8154785], acc: [0.875]
# Loss at epoch 23 step 15: [0.00029175], acc: [1.]
# Loss at epoch 23 step 16: [0.5800799], acc: [0.875]
# Loss at epoch 23 step 17: [0.34757504], acc: [0.875]
# Loss at epoch 23 step 18: [0.43087724], acc: [0.875]
# Loss at epoch 23 step 19: [0.37140816], acc: [0.875]
# Loss at epoch 24 step 0: [0.14797701], acc: [1.]
# Loss at epoch 24 step 1: [0.23838355], acc: [0.875]
# Loss at epoch 24 step 2: [0.05302519], acc: [1.]
# Loss at epoch 24 step 3: [0.21922514], acc: [1.]
# Loss at epoch 24 step 4: [0.36597604], acc: [0.875]
# Loss at epoch 24 step 5: [0.04112805], acc: [1.]
# Loss at epoch 24 step 6: [0.16042714], acc: [0.875]
# Loss at epoch 24 step 7: [0.20634946], acc: [0.875]
# Loss at epoch 24 step 8: [0.08724326], acc: [1.]
# Loss at epoch 24 step 9: [0.26019645], acc: [0.75]
# Loss at epoch 24 step 10: [0.02016912], acc: [1.]
# Loss at epoch 24 step 11: [0.17801553], acc: [1.]
# Loss at epoch 24 step 12: [0.11742461], acc: [0.875]
# Loss at epoch 24 step 13: [0.08407765], acc: [1.]
# Loss at epoch 24 step 14: [1.6223661], acc: [0.75]
# Loss at epoch 24 step 15: [0.00080232], acc: [1.]
# Loss at epoch 24 step 16: [0.00396926], acc: [1.]
# Loss at epoch 24 step 17: [0.08500831], acc: [1.]
# Loss at epoch 24 step 18: [0.9274516], acc: [0.625]
# Loss at epoch 24 step 19: [0.48765472], acc: [0.625]
# Loss at epoch 25 step 0: [0.1367188], acc: [1.]
# Loss at epoch 25 step 1: [0.23544054], acc: [0.875]
# Loss at epoch 25 step 2: [0.03912942], acc: [1.]
# Loss at epoch 25 step 3: [0.24411875], acc: [0.875]
# Loss at epoch 25 step 4: [0.26885766], acc: [0.75]
# Loss at epoch 25 step 5: [0.05539238], acc: [1.]
# Loss at epoch 25 step 6: [0.4699933], acc: [0.875]
# Loss at epoch 25 step 7: [0.39486355], acc: [0.875]
# Loss at epoch 25 step 8: [0.28099072], acc: [0.75]
# Loss at epoch 25 step 9: [0.581991], acc: [0.625]
# Loss at epoch 25 step 10: [0.03505918], acc: [1.]
# Loss at epoch 25 step 11: [0.18910913], acc: [0.875]
# Loss at epoch 25 step 12: [0.03136022], acc: [1.]
# Loss at epoch 25 step 13: [1.5683744], acc: [0.75]
# Loss at epoch 25 step 14: [0.5022204], acc: [0.75]
# Loss at epoch 25 step 15: [0.00765544], acc: [1.]
# Loss at epoch 25 step 16: [0.01976702], acc: [1.]
# Loss at epoch 25 step 17: [0.01433523], acc: [1.]
# Loss at epoch 25 step 18: [0.02839728], acc: [1.]
# Loss at epoch 25 step 19: [0.35693058], acc: [0.625]
# Loss at epoch 26 step 0: [0.15586352], acc: [0.875]
# Loss at epoch 26 step 1: [0.04639461], acc: [1.]
# Loss at epoch 26 step 2: [1.6118982], acc: [0.75]
# Loss at epoch 26 step 3: [0.15462525], acc: [0.875]
# Loss at epoch 26 step 4: [0.801943], acc: [0.625]
# Loss at epoch 26 step 5: [0.19955148], acc: [0.875]
# Loss at epoch 26 step 6: [0.23953426], acc: [0.875]
# Loss at epoch 26 step 7: [0.46793544], acc: [0.75]
# Loss at epoch 26 step 8: [0.28326112], acc: [1.]
# Loss at epoch 26 step 9: [0.24899381], acc: [1.]
# Loss at epoch 26 step 10: [0.20177315], acc: [1.]
# Loss at epoch 26 step 11: [0.12893544], acc: [0.875]
# Loss at epoch 26 step 12: [0.07493792], acc: [1.]
# Loss at epoch 26 step 13: [0.08627545], acc: [1.]
# Loss at epoch 26 step 14: [0.52904546], acc: [0.75]
# Loss at epoch 26 step 15: [0.00223854], acc: [1.]
# Loss at epoch 26 step 16: [0.97051287], acc: [0.875]
# Loss at epoch 26 step 17: [0.13024954], acc: [0.875]
# Loss at epoch 26 step 18: [0.13545378], acc: [1.]
# Loss at epoch 26 step 19: [0.28795052], acc: [0.875]
# Loss at epoch 27 step 0: [0.21907891], acc: [0.875]
# Loss at epoch 27 step 1: [0.06202023], acc: [1.]
# Loss at epoch 27 step 2: [0.05739031], acc: [1.]
# Loss at epoch 27 step 3: [0.35576826], acc: [0.875]
# Loss at epoch 27 step 4: [0.570671], acc: [0.75]
# Loss at epoch 27 step 5: [0.03582854], acc: [1.]
# Loss at epoch 27 step 6: [0.06210877], acc: [1.]
# Loss at epoch 27 step 7: [0.30456367], acc: [0.875]
# Loss at epoch 27 step 8: [0.37892467], acc: [0.75]
# Loss at epoch 27 step 9: [0.44021922], acc: [0.875]
# Loss at epoch 27 step 10: [0.15474758], acc: [1.]
# Loss at epoch 27 step 11: [0.17984277], acc: [1.]
# Loss at epoch 27 step 12: [0.06037782], acc: [1.]
# Loss at epoch 27 step 13: [0.06784797], acc: [1.]
# Loss at epoch 27 step 14: [0.12287354], acc: [0.875]
# Loss at epoch 27 step 15: [0.00807683], acc: [1.]
# Loss at epoch 27 step 16: [0.01192374], acc: [1.]
# Loss at epoch 27 step 17: [0.00253958], acc: [1.]
# Loss at epoch 27 step 18: [0.02075925], acc: [1.]
# Loss at epoch 27 step 19: [1.8019966], acc: [0.875]
# Loss at epoch 28 step 0: [0.3981139], acc: [0.875]
# Loss at epoch 28 step 1: [0.00023248], acc: [1.]
# Loss at epoch 28 step 2: [0.00273813], acc: [1.]
# Loss at epoch 28 step 3: [0.26000762], acc: [0.875]
# Loss at epoch 28 step 4: [0.6557236], acc: [0.75]
# Loss at epoch 28 step 5: [0.00492061], acc: [1.]
# Loss at epoch 28 step 6: [0.02147624], acc: [1.]
# Loss at epoch 28 step 7: [0.40666154], acc: [0.75]
# Loss at epoch 28 step 8: [0.40644744], acc: [0.75]
# Loss at epoch 28 step 9: [0.51363194], acc: [0.625]
# Loss at epoch 28 step 10: [0.17008772], acc: [1.]
# Loss at epoch 28 step 11: [0.2924739], acc: [0.875]
# Loss at epoch 28 step 12: [0.17616181], acc: [1.]
# Loss at epoch 28 step 13: [0.22702321], acc: [1.]
# Loss at epoch 28 step 14: [0.4387105], acc: [0.75]
# Loss at epoch 28 step 15: [0.05858415], acc: [1.]
# Loss at epoch 28 step 16: [0.31220224], acc: [0.875]
# Loss at epoch 28 step 17: [0.18616688], acc: [1.]
# Loss at epoch 28 step 18: [0.10593548], acc: [1.]
# Loss at epoch 28 step 19: [0.29830205], acc: [0.875]
# Loss at epoch 29 step 0: [0.26509234], acc: [0.875]
# Loss at epoch 29 step 1: [0.03324436], acc: [1.]
# Loss at epoch 29 step 2: [0.04744626], acc: [1.]
# Loss at epoch 29 step 3: [0.18187782], acc: [1.]
# Loss at epoch 29 step 4: [0.09218226], acc: [1.]
# Loss at epoch 29 step 5: [0.01477549], acc: [1.]
# Loss at epoch 29 step 6: [0.01458125], acc: [1.]
# Loss at epoch 29 step 7: [0.18482816], acc: [0.875]
# Loss at epoch 29 step 8: [0.26908907], acc: [0.875]
# Loss at epoch 29 step 9: [0.12223645], acc: [1.]
# Loss at epoch 29 step 10: [0.00305611], acc: [1.]
# Loss at epoch 29 step 11: [0.10269836], acc: [0.875]
# Loss at epoch 29 step 12: [0.02164893], acc: [1.]
# Loss at epoch 29 step 13: [0.01017589], acc: [1.]
# Loss at epoch 29 step 14: [0.00057562], acc: [1.]
# Loss at epoch 29 step 15: [2.2361191e-05], acc: [1.]
# Loss at epoch 29 step 16: [0.0009437], acc: [1.]
# Loss at epoch 29 step 17: [0.01400804], acc: [1.]
# Loss at epoch 29 step 18: [0.12653005], acc: [0.875]
# Loss at epoch 29 step 19: [1.9444157], acc: [0.875]
# Loss at epoch 30 step 0: [0.39617878], acc: [0.875]
# Loss at epoch 30 step 1: [0.11621175], acc: [0.875]
# Loss at epoch 30 step 2: [0.00911528], acc: [1.]
# Loss at epoch 30 step 3: [0.07478774], acc: [1.]
# Loss at epoch 30 step 4: [0.00474908], acc: [1.]
# Loss at epoch 30 step 5: [0.00118419], acc: [1.]
# Loss at epoch 30 step 6: [0.01900958], acc: [1.]
# Loss at epoch 30 step 7: [0.12158805], acc: [0.875]
# Loss at epoch 30 step 8: [0.04978444], acc: [1.]
# Loss at epoch 30 step 9: [0.06528215], acc: [1.]
# Loss at epoch 30 step 10: [0.04890261], acc: [1.]
# Loss at epoch 30 step 11: [0.01781246], acc: [1.]
# Loss at epoch 30 step 12: [0.00828484], acc: [1.]
# Loss at epoch 30 step 13: [0.01268467], acc: [1.]
# Loss at epoch 30 step 14: [0.32606652], acc: [0.875]
# Loss at epoch 30 step 15: [0.00045478], acc: [1.]
# Loss at epoch 30 step 16: [0.9933172], acc: [0.875]
# Loss at epoch 30 step 17: [0.00450104], acc: [1.]
# Loss at epoch 30 step 18: [0.04818912], acc: [1.]
# Loss at epoch 30 step 19: [0.24466847], acc: [0.875]
# Loss at epoch 31 step 0: [0.04099976], acc: [1.]
# Loss at epoch 31 step 1: [0.01913641], acc: [1.]
# Loss at epoch 31 step 2: [0.03937649], acc: [1.]
# Loss at epoch 31 step 3: [0.3357402], acc: [0.875]
# Loss at epoch 31 step 4: [0.5781996], acc: [0.75]
# Loss at epoch 31 step 5: [0.01306854], acc: [1.]
# Loss at epoch 31 step 6: [0.06933679], acc: [1.]
# Loss at epoch 31 step 7: [0.16423018], acc: [0.875]
# Loss at epoch 31 step 8: [0.06957527], acc: [1.]
# Loss at epoch 31 step 9: [0.18398029], acc: [1.]
# Loss at epoch 31 step 10: [0.10137037], acc: [1.]
# Loss at epoch 31 step 11: [0.1627512], acc: [1.]
# Loss at epoch 31 step 12: [0.03390343], acc: [1.]
# Loss at epoch 31 step 13: [0.09795815], acc: [1.]
# Loss at epoch 31 step 14: [0.0288542], acc: [1.]
# Loss at epoch 31 step 15: [0.00032647], acc: [1.]
# Loss at epoch 31 step 16: [0.36041313], acc: [0.875]
# Loss at epoch 31 step 17: [0.00054196], acc: [1.]
# Loss at epoch 31 step 18: [0.00558443], acc: [1.]
# Loss at epoch 31 step 19: [0.48172984], acc: [0.875]
# Loss at epoch 32 step 0: [0.01767], acc: [1.]
# Loss at epoch 32 step 1: [0.00049595], acc: [1.]
# Loss at epoch 32 step 2: [0.00095813], acc: [1.]
# Loss at epoch 32 step 3: [0.0856512], acc: [1.]
# Loss at epoch 32 step 4: [1.0991441], acc: [0.625]
# Loss at epoch 32 step 5: [0.00379436], acc: [1.]
# Loss at epoch 32 step 6: [0.00703296], acc: [1.]
# Loss at epoch 32 step 7: [0.17879921], acc: [0.875]
# Loss at epoch 32 step 8: [0.00764424], acc: [1.]
# Loss at epoch 32 step 9: [0.03894728], acc: [1.]
# Loss at epoch 32 step 10: [0.08977144], acc: [1.]
# Loss at epoch 32 step 11: [0.181229], acc: [0.875]
# Loss at epoch 32 step 12: [0.03323901], acc: [1.]
# Loss at epoch 32 step 13: [0.06476737], acc: [1.]
# Loss at epoch 32 step 14: [0.13175054], acc: [0.875]
# Loss at epoch 32 step 15: [0.00177963], acc: [1.]
# Loss at epoch 32 step 16: [0.05961116], acc: [1.]
# Loss at epoch 32 step 17: [0.00111697], acc: [1.]
# Loss at epoch 32 step 18: [0.02273888], acc: [1.]
# Loss at epoch 32 step 19: [0.45900127], acc: [0.875]
# Loss at epoch 33 step 0: [0.01324976], acc: [1.]
# Loss at epoch 33 step 1: [0.00252289], acc: [1.]
# Loss at epoch 33 step 2: [0.00278282], acc: [1.]
# Loss at epoch 33 step 3: [0.17791611], acc: [0.875]
# Loss at epoch 33 step 4: [0.0892637], acc: [1.]
# Loss at epoch 33 step 5: [0.00185237], acc: [1.]
# Loss at epoch 33 step 6: [0.06352083], acc: [1.]
# Loss at epoch 33 step 7: [0.32041067], acc: [0.875]
# Loss at epoch 33 step 8: [0.00558629], acc: [1.]
# Loss at epoch 33 step 9: [0.15781616], acc: [0.875]
# Loss at epoch 33 step 10: [0.00084379], acc: [1.]
# Loss at epoch 33 step 11: [0.09951532], acc: [0.875]
# Loss at epoch 33 step 12: [0.0152539], acc: [1.]
# Loss at epoch 33 step 13: [0.02431122], acc: [1.]
# Loss at epoch 33 step 14: [0.00309098], acc: [1.]
# Loss at epoch 33 step 15: [1.1230989], acc: [0.875]
# Loss at epoch 33 step 16: [0.0058251], acc: [1.]
# Loss at epoch 33 step 17: [0.00650404], acc: [1.]
# Loss at epoch 33 step 18: [0.01161261], acc: [1.]
# Loss at epoch 33 step 19: [0.28303525], acc: [0.875]
# Loss at epoch 34 step 0: [0.0008042], acc: [1.]
# Loss at epoch 34 step 1: [0.00011145], acc: [1.]
# Loss at epoch 34 step 2: [3.9637694e-06], acc: [1.]
# Loss at epoch 34 step 3: [0.49218804], acc: [0.875]
# Loss at epoch 34 step 4: [0.02867609], acc: [1.]
# Loss at epoch 34 step 5: [2.6077305e-06], acc: [1.]
# Loss at epoch 34 step 6: [0.00320626], acc: [1.]
# Loss at epoch 34 step 7: [1.5733224], acc: [0.75]
# Loss at epoch 34 step 8: [0.00305861], acc: [1.]
# Loss at epoch 34 step 9: [0.03306925], acc: [1.]
# Loss at epoch 34 step 10: [0.02847674], acc: [1.]
# Loss at epoch 34 step 11: [0.38625008], acc: [0.875]
# Loss at epoch 34 step 12: [0.09239763], acc: [1.]
# Loss at epoch 34 step 13: [0.32628316], acc: [0.875]
# Loss at epoch 34 step 14: [0.04484008], acc: [1.]
# Loss at epoch 34 step 15: [0.00445286], acc: [1.]
# Loss at epoch 34 step 16: [0.01668963], acc: [1.]
# Loss at epoch 34 step 17: [0.00368009], acc: [1.]
# Loss at epoch 34 step 18: [1.2343057], acc: [0.75]
# Loss at epoch 34 step 19: [0.06186445], acc: [1.]
# Loss at epoch 35 step 0: [0.14973415], acc: [1.]
# Loss at epoch 35 step 1: [0.02240822], acc: [1.]
# Loss at epoch 35 step 2: [0.01129763], acc: [1.]
# Loss at epoch 35 step 3: [0.21754858], acc: [0.875]
# Loss at epoch 35 step 4: [0.67515314], acc: [0.75]
# Loss at epoch 35 step 5: [0.00398181], acc: [1.]
# Loss at epoch 35 step 6: [0.31090456], acc: [0.875]
# Loss at epoch 35 step 7: [0.7909658], acc: [0.75]
# Loss at epoch 35 step 8: [0.01768676], acc: [1.]
# Loss at epoch 35 step 9: [0.19325006], acc: [0.875]
# Loss at epoch 35 step 10: [0.11266634], acc: [1.]
# Loss at epoch 35 step 11: [0.1703336], acc: [0.875]
# Loss at epoch 35 step 12: [0.11226225], acc: [1.]
# Loss at epoch 35 step 13: [0.05637077], acc: [1.]
# Loss at epoch 35 step 14: [0.036443], acc: [1.]
# Loss at epoch 35 step 15: [0.01999166], acc: [1.]
# Loss at epoch 35 step 16: [0.21918616], acc: [0.875]
# Loss at epoch 35 step 17: [0.05043952], acc: [1.]
# Loss at epoch 35 step 18: [0.20414005], acc: [0.875]
# Loss at epoch 35 step 19: [0.0987789], acc: [1.]
# Loss at epoch 36 step 0: [0.00357499], acc: [1.]
# Loss at epoch 36 step 1: [0.0008038], acc: [1.]
# Loss at epoch 36 step 2: [0.00019213], acc: [1.]
# Loss at epoch 36 step 3: [0.10639291], acc: [1.]
# Loss at epoch 36 step 4: [0.15573415], acc: [0.875]
# Loss at epoch 36 step 5: [4.593382e-05], acc: [1.]
# Loss at epoch 36 step 6: [7.502005e-05], acc: [1.]
# Loss at epoch 36 step 7: [0.2436609], acc: [0.875]
# Loss at epoch 36 step 8: [0.00025714], acc: [1.]
# Loss at epoch 36 step 9: [0.23004375], acc: [0.75]
# Loss at epoch 36 step 10: [0.00075174], acc: [1.]
# Loss at epoch 36 step 11: [0.31296828], acc: [0.875]
# Loss at epoch 36 step 12: [0.00233477], acc: [1.]
# Loss at epoch 36 step 13: [0.00488669], acc: [1.]
# Loss at epoch 36 step 14: [0.02919224], acc: [1.]
# Loss at epoch 36 step 15: [1.44847645e-05], acc: [1.]
# Loss at epoch 36 step 16: [0.2025329], acc: [0.875]
# Loss at epoch 36 step 17: [5.587142e-05], acc: [1.]
# Loss at epoch 36 step 18: [0.10428964], acc: [0.875]
# Loss at epoch 36 step 19: [0.24843656], acc: [0.875]
# Final loss: [0.24843656]

# %%
'''
模型校验
'''
with fluid.dygraph.guard():
    model, _ = fluid.load_dygraph("vgg")
    vgg = VGGNet()
    vgg.load_dict(model)
    vgg.eval()
    accs = []
    for batch_id, data in enumerate(eval_reader()):
        dy_x_data = np.array([x[0] for x in data]).astype('float32')
        y_data = np.array([x[1] for x in data]).astype('int')
        y_data = y_data[:, np.newaxis]
        
        img = fluid.dygraph.to_variable(dy_x_data)
        label = fluid.dygraph.to_variable(y_data)

        out, acc = vgg(img, label)
        lab = np.argsort(out.numpy())
        accs.append(acc.numpy()[0])
print(np.mean(accs))
# Out:
# 0.875

# %% [markdown]
# # **五、模型预测**

# %%
# def load_image(img_path):
#     '''
#     预测图片预处理
#     '''
#     img = Image.open(img_path) 
#     if img.mode != 'RGB': 
#         img = img.convert('RGB') 
#     img = img.resize((224, 224), Image.BILINEAR)
#     img = np.array(img).astype('float32') 
#     img = img.transpose((2, 0, 1))  # HWC to CHW 
#     img = img/255                # 像素值归一化 
#     return img

# label_dic = train_parameters['label_dict']

# '''
# 模型预测
# '''
# with fluid.dygraph.guard():
#     model, _ = fluid.dygraph.load_dygraph("vgg")
#     vgg = VGGNet()
#     vgg.load_dict(model)
#     vgg.eval()
    
#     #展示预测图片
#     infer_path='/home/aistudio/data/data23615/infer_mask01.jpg'
#     img = Image.open(infer_path)
#     plt.imshow(img)          #根据数组绘制图像
#     plt.show()               #显示图像

#     #对预测图片进行预处理
#     infer_imgs = []
#     infer_imgs.append(load_image(infer_path))
#     infer_imgs = np.array(infer_imgs)
   
#     for  i in range(len(infer_imgs)):
#         data = infer_imgs[i]
#         dy_x_data = np.array(data).astype('float32')
#         dy_x_data=dy_x_data[np.newaxis,:, : ,:]
#         img = fluid.dygraph.to_variable(dy_x_data)
#         out = vgg(img)
#         lab = np.argmax(out.numpy())  #argmax():返回最大数的索引
#         print("第{}个样本,被预测为：{}".format(i+1,label_dic[str(lab)]))
        
# print("结束")
